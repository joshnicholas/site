# %%
import pandas as pd 
from sudulunu.helpers import dumper, pp

# %%
data = pd.read_csv('/Users/josh/Github/site/python/scrap/together.csv')

data = data.loc[data['Date'] > "2025-02-10"]

for index, row in data.iterrows():
    print(row['Date'], row['Subject'])

pp(data)
# Out:
# 2025-02-11 ('An urban transportation scene featuring a tram/streetcar stop with trees and street furniture, drawn in a quick sketch style capturing the essence of city life',)
# 2025-02-11 ('A segmented citrus fruit (likely an orange or mandarin) sitting in a small dish or plate, with the segments arranged in a fan-like pattern showing the natural division of the fruit',)
#          Date                                              Title  \
# 0  2025-02-11  My friend asked me for a #scribble of some tra...
# 1  2025-02-11  Someone nicked a banana halfway through #offic...
#
#                                             img_path Caption  \
# 0  bafkreiebe4cdzj5eoovpgpf25yri6a3gcbe3pz4bepvd6...     NaN
# 1  bafkreiha44zujrbyr3m34rhjnksggnonx2pal3dhiiteu...     NaN
#
#                                              Colours  \
# 0  (['Black/grey ink', 'Off-white paper', 'Backgr...
# 1              (['Black', 'Grey', 'White (paper)'],)
#
# ...
